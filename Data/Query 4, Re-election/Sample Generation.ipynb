# %% [markdown]
# **Sample Generation for Query 4: Re-election**

# %%
import random

# countries grouped by continent
continents = {
    "Africa": [
        "Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cabo Verde", "Cameroon",
        "Central African Republic", "Chad", "Comoros", "Congo", "Democratic Republic of the Congo", "Djibouti",
        "Egypt", "Equatorial Guinea", "Eritrea", "Eswatini", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea",
        "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali",
        "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", 
        "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", 
        "South Sudan", "Sudan", "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"
    ],
    "Asia": [
        "Afghanistan", "Armenia", "Azerbaijan", "Bahrain", "Bangladesh", "Bhutan", "Brunei", "Cambodia", 
        "China", "Cyprus", "Georgia", "India", "Indonesia", "Iran", "Iraq", "Israel", "Japan", "Jordan", 
        "Kazakhstan", "Kuwait", "Kyrgyzstan", "Laos", "Lebanon", "Malaysia", "Maldives", "Mongolia", "Myanmar", 
        "Nepal", "North Korea", "Oman", "Pakistan", "Philippines", "Qatar", "Saudi Arabia", "Singapore", 
        "South Korea", "Sri Lanka", "Syria", "Tajikistan", "Thailand", "Timor-Leste", "Turkmenistan", 
        "United Arab Emirates", "Uzbekistan", "Vietnam", "Yemen"
    ],
    "Europe": [
        "Albania", "Andorra", "Austria", "Belarus", "Belgium", "Bosnia and Herzegovina", "Bulgaria", "Croatia",
        "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", 
        "Ireland", "Italy", "Latvia", "Liechtenstein", "Lithuania", "Luxembourg", "Malta", "Moldova", 
        "Monaco", "Montenegro", "Netherlands", "North Macedonia", "Norway", "Poland", "Portugal", "Romania", 
        "Russia", "San Marino", "Serbia", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", 
        "Ukraine", "United Kingdom"
    ],
    "North America": [
        "Antigua and Barbuda", "Bahamas", "Barbados", "Belize", "Canada", "Costa Rica", "Cuba", "Dominica",
        "Dominican Republic", "El Salvador", "Grenada", "Guatemala", "Haiti", "Honduras", "Jamaica", "Mexico",
        "Nicaragua", "Panama", "Saint Kitts and Nevis", "Saint Lucia", "Saint Vincent and the Grenadines", 
        "Trinidad and Tobago", "United States"
    ],
    "Oceania": [
        "Australia", "Fiji", "Kiribati", "Marshall Islands", "Micronesia", "Nauru", "New Zealand", "Palau", 
        "Papua New Guinea", "Samoa", "Solomon Islands", "Tonga", "Tuvalu", "Vanuatu"
    ],
    "South America": [
        "Argentina", "Bolivia", "Brazil", "Chile", "Colombia", "Ecuador", "Guyana", "Paraguay", "Peru", 
        "Suriname", "Uruguay", "Venezuela"
    ]
}

# sample sizes proportional to continent size
# (this was done by finding how many countries proportional to the number of countries in the continent, i.e. finding the percentage of the number of countries in each continent across the total number of countries and fiding an approximation)
sample_sizes = {
    "Africa": 14,
    "Asia": 13,
    "Europe": 12,
    "North America": 6,
    "Oceania": 4,
    "South America": 3
}

# random sampling for each continent
sample = {continent: random.sample(countries, size) for continent, (countries, size) in zip(continents.keys(), zip(continents.values(), sample_sizes.values()))}
for continent, countries in sample.items():
    print(f"{continent}: {', '.join(countries)}")
# Out:
# Africa: Mozambique, Burundi, Senegal, Malawi, Congo, Mauritius, Algeria, Guinea-Bissau, Ivory Coast, Namibia, Egypt, Burkina Faso, South Africa, Kenya
# Asia: Brunei, Azerbaijan, Cambodia, Iran, Maldives, Yemen, Myanmar, Bahrain, Armenia, South Korea, Qatar, Bangladesh, Indonesia
# Europe: France, Andorra, Greece, Monaco, Norway, Luxembourg, Russia, Ukraine, Croatia, United Kingdom, Germany, San Marino
# North America: Dominica, Saint Lucia, Bahamas, Belize, Canada, Panama
# Oceania: Nauru, Fiji, Samoa, Palau
# South America: Colombia, Paraguay, Suriname

# %% [markdown]
# This sample changes everytime, and due to the lack of seed, and as some data is less available than other data, we ended up with the sample below:
#
# North America
# - El Salvador (SLV)
# - United States of America (USA)
# - Panama (PAN)
# - Costa Rica (CRI)
# - Samoa (WSM)
# - Guatemala (GTM)
# - Barbados (BRB)
#
# South America
# - Argentina (ARG)
# - Chile (CHL)
# - Guyana (GUY)
#
# Europe
# - Albania (ALB)
# - Bulgaria (BGR)
# - Belarus (BLR)
# - Russia (RUS)
# - Switzerland (CHE)
# - Estonia (EST)
# - Denmark (DNK)
# - Hungary (HUN)
# - Ireland (IRL)
# - Luxembourg (LUX)
# - Slovakia (SVK)
# - Cyprus (CYP)
# - Greece (GRC)
# - United Kingdom (GBR)
#
#
# Oceania
# - Solomon Islands (SLB)
# - Palau (PLW)
# - New Zealand (NZL)
#
# Asia
# - Azerbaijan (AZE)
# - Kyrgyzstan (KGZ)
# - Turkmenistan (TKM)
# - Iraq (IRQ)
# - Indonesia (IDN)
# - Bangladesh (BGD)
# - Israel (ISR)
# - Myanmar (MMR)
# - Oman (OMN)
# - Pakistan (PAK)
# - Singapore (SGP)
#
# Africa
# - Benin (BEN)
# - Botswana (BWA)
# - Cape Verde (CPV)
# - Congo (Republic of the Congo) (COG)
# - Egypt (EGY)
# - Gambia (GMB)
# - Lesotho (LSO)
# - Liberia (LBR)
# - Rwanda (RWA) (RAW was a typo)
# - Senegal (SEN)
# - Seychelles (SYC)
# - Sudan (SDN)
# - Zimbabwe (ZWE)
